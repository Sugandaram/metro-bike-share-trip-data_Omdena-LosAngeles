# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import os
os.chdir("D:\Omdena-LosAngeles-AnalyzingOpenDataAboutLA\Los Angeles Metro Bike Share Trip Data")

# %%
MB = pd.read_csv("metro_bike_share_trip_data.csv")

# %%
MB
# Out:
#          Trip ID  Duration               Start Time                 End Time  \
# 0       18222186     15060  2017-01-19T17:05:00.000  2017-01-19T21:16:00.000
# 1        9518671     77160  2016-10-09T14:37:00.000  2016-10-10T12:03:00.000
# 2       20444932     86400  2017-02-18T10:15:00.000  2017-02-20T15:20:00.000
# 3       20905031     18840  2017-02-27T12:26:00.000  2017-02-27T17:40:00.000
# 4       21031476     86400  2017-02-27T20:26:00.000  2017-03-01T09:49:00.000
# ...          ...       ...                      ...                      ...
# 132422   4907293      2520  2016-08-06T14:35:00.000  2016-08-06T15:17:00.000
# 132423   4908300      1080  2016-08-08T07:18:00.000  2016-08-08T07:36:00.000
# 132424   4726795      1500  2016-07-30T15:52:00.000  2016-07-30T16:17:00.000
# 132425   5034026       780  2016-08-12T09:17:00.000  2016-08-12T09:30:00.000
# 132426   5250466       300  2016-09-06T18:16:00.000  2016-09-06T18:21:00.000
#
# ...

# %%
MB1 = MB.copy()

# %%
MB1.head()
# Out:
#     Trip ID  Duration               Start Time                 End Time  \
# 0  18222186     15060  2017-01-19T17:05:00.000  2017-01-19T21:16:00.000
# 1   9518671     77160  2016-10-09T14:37:00.000  2016-10-10T12:03:00.000
# 2  20444932     86400  2017-02-18T10:15:00.000  2017-02-20T15:20:00.000
# 3  20905031     18840  2017-02-27T12:26:00.000  2017-02-27T17:40:00.000
# 4  21031476     86400  2017-02-27T20:26:00.000  2017-03-01T09:49:00.000
#
#    Starting Station ID  Starting Station Latitude  Starting Station Longitude  \
# 0               3031.0                  34.044701                 -118.252441
# 1                  NaN                        NaN                         NaN
# 2               3026.0                  34.063179                 -118.245880
# 3               3023.0                  34.050911                 -118.240967
# 4               3008.0                  34.046612                 -118.262733
#
# ...

# %%
MB1.tail()
# Out:
#         Trip ID  Duration               Start Time                 End Time  \
# 132422  4907293      2520  2016-08-06T14:35:00.000  2016-08-06T15:17:00.000
# 132423  4908300      1080  2016-08-08T07:18:00.000  2016-08-08T07:36:00.000
# 132424  4726795      1500  2016-07-30T15:52:00.000  2016-07-30T16:17:00.000
# 132425  5034026       780  2016-08-12T09:17:00.000  2016-08-12T09:30:00.000
# 132426  5250466       300  2016-09-06T18:16:00.000  2016-09-06T18:21:00.000
#
#         Starting Station ID  Starting Station Latitude  \
# 132422               3052.0                  34.051102
# 132423               3027.0                  34.049980
# 132424               3014.0                  34.056610
# 132425               3036.0                  34.039188
# 132426               3046.0                  34.053021
#
#         Starting Station Longitude  Ending Station ID  \
# 132422                  -118.26456             3052.0
# 132423                  -118.24716             3057.0
# ...

# %%
MB1.isnull().sum()
# Out:
# Trip ID                                   0
# Duration                                  0
# Start Time                                0
# End Time                                  0
# Starting Station ID                      19
# Starting Station Latitude                48
# Starting Station Longitude               48
# Ending Station ID                        96
# Ending Station Latitude                1051
# Ending Station Longitude               1051
# Bike ID                                  10
# Plan Duration                           766
# Trip Route Category                       0
# Passholder Type                           0
# Starting Lat-Long                     33805
# Ending Lat-Long                        1051
# Neighborhood Councils (Certified)     33837
# Council Districts                     33837
# Zip Codes                             33837
# LA Specific Plans                    116624
# Precinct Boundaries                    1099
# ...

# %%
sns.heatmap(MB1.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <AxesSubplot: >

# %%
MB1.duplicated().sum()
# Out:
# 243

# %%
[features for features in MB1.columns if MB1[features].duplicated().sum()>0]
# Out:
# ['Trip ID',
#  'Duration',
#  'Start Time',
#  'End Time',
#  'Starting Station ID',
#  'Starting Station Latitude',
#  'Starting Station Longitude',
#  'Ending Station ID',
#  'Ending Station Latitude',
#  'Ending Station Longitude',
#  'Bike ID',
#  'Plan Duration',
#  'Trip Route Category',
#  'Passholder Type',
#  'Starting Lat-Long',
#  'Ending Lat-Long',
#  'Neighborhood Councils (Certified)',
#  'Council Districts',
#  'Zip Codes',
#  'LA Specific Plans',
#  'Precinct Boundaries',
#  'Census Tracts']

# %% [markdown]
# ## got 243 duplicate values in this data set
# ## drop this all duplicate values

# %%
MB2 = MB1.copy()

# %%
MB2.drop_duplicates(inplace = True)

# %%
MB2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##   I will check again null values

# %%
MB1.isnull().sum()
# Out:
# Trip ID                                   0
# Duration                                  0
# Start Time                                0
# End Time                                  0
# Starting Station ID                      19
# Starting Station Latitude                48
# Starting Station Longitude               48
# Ending Station ID                        96
# Ending Station Latitude                1051
# Ending Station Longitude               1051
# Bike ID                                  10
# Plan Duration                           766
# Trip Route Category                       0
# Passholder Type                           0
# Starting Lat-Long                     33805
# Ending Lat-Long                        1051
# Neighborhood Councils (Certified)     33837
# Council Districts                     33837
# Zip Codes                             33837
# LA Specific Plans                    116624
# Precinct Boundaries                    1099
# ...

# %%
MB2.isnull().sum()
# Out:
# Trip ID                                   0
# Duration                                  0
# Start Time                                0
# End Time                                  0
# Starting Station ID                      19
# Starting Station Latitude                48
# Starting Station Longitude               48
# Ending Station ID                        96
# Ending Station Latitude                1051
# Ending Station Longitude               1051
# Bike ID                                  10
# Plan Duration                           766
# Trip Route Category                       0
# Passholder Type                           0
# Starting Lat-Long                     33805
# Ending Lat-Long                        1051
# Neighborhood Councils (Certified)     33837
# Council Districts                     33837
# Zip Codes                             33837
# LA Specific Plans                    116410
# Precinct Boundaries                    1099
# ...

# %% [markdown]
# ## There are slight changes in the null values in the LA Specific Plans column

# %% [markdown]
# ## use Dropna values in this dataset

# %%
MB2.dropna(inplace = True)

# %%
MB2.isnull().sum()
# Out:
# Trip ID                              0
# Duration                             0
# Start Time                           0
# End Time                             0
# Starting Station ID                  0
# Starting Station Latitude            0
# Starting Station Longitude           0
# Ending Station ID                    0
# Ending Station Latitude              0
# Ending Station Longitude             0
# Bike ID                              0
# Plan Duration                        0
# Trip Route Category                  0
# Passholder Type                      0
# Starting Lat-Long                    0
# Ending Lat-Long                      0
# Neighborhood Councils (Certified)    0
# Council Districts                    0
# Zip Codes                            0
# LA Specific Plans                    0
# Precinct Boundaries                  0
# Census Tracts                        0
# dtype: int64

# %%
sns.heatmap(MB2.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## there is no nan values

# %%
MB2.size
# Out:
# 258632

# %%
MB.size
# Out:
# 2913394

# %% [markdown]
# ## there are lot of different in this dataset after drop nan values
# ## Before = 2913394
# ## After = 258632

# %%
MB3 = MB2.copy()

# %%
MB3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11756 entries, 2088 to 132426
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Trip ID                            11756 non-null  int64
#  1   Duration                           11756 non-null  int64
#  2   Start Time                         11756 non-null  object
#  3   End Time                           11756 non-null  object
#  4   Starting Station ID                11756 non-null  float64
#  5   Starting Station Latitude          11756 non-null  float64
#  6   Starting Station Longitude         11756 non-null  float64
#  7   Ending Station ID                  11756 non-null  float64
#  8   Ending Station Latitude            11756 non-null  float64
#  9   Ending Station Longitude           11756 non-null  float64
#  10  Bike ID                            11756 non-null  float64
# ...

# %%
MB3.describe()
# Out:
#             Trip ID      Duration  Starting Station ID  \
# count  1.175600e+04  11756.000000         11756.000000
# mean   8.331759e+06   1543.310650          3039.285046
# std    4.109083e+06   4593.679351            21.358721
# min    1.912818e+06     60.000000          3005.000000
# 25%    5.049382e+06    480.000000          3023.000000
# 50%    6.817526e+06    720.000000          3035.000000
# 75%    1.188679e+07   1260.000000          3056.000000
# max    1.705688e+07  86400.000000          3082.000000
#
#        Starting Station Latitude  Starting Station Longitude  \
# count               11756.000000                11756.000000
# mean                   34.048290                 -118.251264
# std                     0.006508                    0.009634
# min                    34.028511                 -118.270813
# 25%                    34.044701                 -118.259048
# 50%                    34.048550                 -118.251579
# ...

# %%
MB3.head()
# Out:
#       Trip ID  Duration               Start Time                 End Time  \
# 2088  2023364      1980  2016-07-08T09:24:00.000  2016-07-08T09:57:00.000
# 2091  2182651      4440  2016-07-09T19:08:00.000  2016-07-09T20:22:00.000
# 2092  2286870      5220  2016-07-10T10:56:00.000  2016-07-10T12:23:00.000
# 2098  2778339       180  2016-07-13T11:52:00.000  2016-07-13T11:55:00.000
# 2118  4683198      1620  2016-07-26T10:08:00.000  2016-07-26T10:35:00.000
#
#       Starting Station ID  Starting Station Latitude  \
# 2088               3045.0                  34.028511
# 2091               3045.0                  34.028511
# 2092               3045.0                  34.028511
# 2098               3045.0                  34.028511
# 2118               3045.0                  34.028511
#
#       Starting Station Longitude  Ending Station ID  Ending Station Latitude  \
# 2088                  -118.25667             3045.0                34.028511
# ...

# %% [markdown]
# ## split date & time (day, month, year, hour, minute)

# %%
MB3["Start Time"] = pd.to_datetime(MB3["Start Time"])
MB3["Start Time"]
# Out:
# 2088     2016-07-08 09:24:00
# 2091     2016-07-09 19:08:00
# 2092     2016-07-10 10:56:00
# 2098     2016-07-13 11:52:00
# 2118     2016-07-26 10:08:00
#                  ...
# 132418   2016-09-28 07:00:00
# 132422   2016-08-06 14:35:00
# 132423   2016-08-08 07:18:00
# 132424   2016-07-30 15:52:00
# 132426   2016-09-06 18:16:00
# Name: Start Time, Length: 11756, dtype: datetime64[ns]

# %%
MB3["Start year"] = MB3["Start Time"].dt.year
MB3["Start Month"] = MB3["Start Time"].dt.month
MB3["Start Day"] = MB3["Start Time"].dt.day

# %%
MB3["End Time"] = pd.to_datetime(MB3["End Time"])
MB3["End Time"]
# Out:
# 2088     2016-07-08 09:57:00
# 2091     2016-07-09 20:22:00
# 2092     2016-07-10 12:23:00
# 2098     2016-07-13 11:55:00
# 2118     2016-07-26 10:35:00
#                  ...
# 132418   2016-09-28 07:13:00
# 132422   2016-08-06 15:17:00
# 132423   2016-08-08 07:36:00
# 132424   2016-07-30 16:17:00
# 132426   2016-09-06 18:21:00
# Name: End Time, Length: 11756, dtype: datetime64[ns]

# %%
MB3["End year"] = MB3["End Time"].dt.year
MB3["End Month"] = MB3["End Time"].dt.month
MB3["End Day"] = MB3["End Time"].dt.day

# %% [markdown]
# ## Directive

# %%
MB3["Start Time"] = pd.to_datetime(MB3["Start Time"])

# %%
MB3["Start Hour"] = MB3["Start Time"].dt.strftime("%H")
MB3["Start Min"] = MB3["Start Time"].dt.strftime("%M")
MB3["Start Sec"] = MB3["Start Time"].dt.strftime("%S")

# %%
MB3["End Time"] = pd.to_datetime(MB3["End Time"])

# %%
MB3["End Hour"] = MB3["End Time"].dt.strftime("%H")
MB3["End Min"] = MB3["End Time"].dt.strftime("%M")
MB3["End Sec"] = MB3["End Time"].dt.strftime("%S")

# %%
MB3.columns
# Out:
# Index(['Trip ID', 'Duration', 'Start Time', 'End Time', 'Starting Station ID',
#        'Starting Station Latitude', 'Starting Station Longitude',
#        'Ending Station ID', 'Ending Station Latitude',
#        'Ending Station Longitude', 'Bike ID', 'Plan Duration',
#        'Trip Route Category', 'Passholder Type', 'Starting Lat-Long',
#        'Ending Lat-Long', 'Neighborhood Councils (Certified)',
#        'Council Districts', 'Zip Codes', 'LA Specific Plans',
#        'Precinct Boundaries', 'Census Tracts', 'Start year', 'Start Month',
#        'Start Day', 'End year', 'End Month', 'End Day', 'Start Hour',
#        'Start Min', 'Start Sec', 'End Hour', 'End Min', 'End Sec'],
#       dtype='object')

# %%
MB3.drop(['Start Time', 'End Time'],axis = 1, inplace = True)

# %%
MB3.head(2)
# Out:
#       Trip ID  Duration  Starting Station ID  Starting Station Latitude  \
# 2088  2023364      1980               3045.0                  34.028511
# 2091  2182651      4440               3045.0                  34.028511
#
#       Starting Station Longitude  Ending Station ID  Ending Station Latitude  \
# 2088                  -118.25667             3045.0                34.028511
# 2091                  -118.25667             3045.0                34.028511
#
#       Ending Station Longitude  Bike ID  Plan Duration  ... Start Day  \
# 2088                -118.25667   5833.0           30.0  ...         8
# 2091                -118.25667   6623.0           30.0  ...         9
#
#      End year End Month End Day  Start Hour  Start Min  Start Sec  End Hour  \
# 2088     2016         7       8          09         24         00        09
# 2091     2016         7       9          19         08         00        20
#
#       End Min  End Sec
# 2088       57       00
# ...

# %%
MB3["Start Hour"] = MB3["Start Hour"].astype('int')
MB3["Start Min"] = MB3["Start Min"].astype('int')
MB3["Start Sec"] = MB3["Start Sec"].astype('int')
MB3["End Hour"] = MB3["End Hour"].astype('int')
MB3["End Min"] = MB3["End Min"].astype('int')
MB3["End Sec"] = MB3["End Sec"].astype('int')

# %%
MB3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11756 entries, 2088 to 132426
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Trip ID                            11756 non-null  int64
#  1   Duration                           11756 non-null  int64
#  2   Starting Station ID                11756 non-null  float64
#  3   Starting Station Latitude          11756 non-null  float64
#  4   Starting Station Longitude         11756 non-null  float64
#  5   Ending Station ID                  11756 non-null  float64
#  6   Ending Station Latitude            11756 non-null  float64
#  7   Ending Station Longitude           11756 non-null  float64
#  8   Bike ID                            11756 non-null  float64
#  9   Plan Duration                      11756 non-null  float64
#  10  Trip Route Category                11756 non-null  object
# ...

# %%
MB4 = MB3.copy()

# %%
MB4.head(5)
# Out:
#       Trip ID  Duration  Starting Station ID  Starting Station Latitude  \
# 2088  2023364      1980               3045.0                  34.028511
# 2091  2182651      4440               3045.0                  34.028511
# 2092  2286870      5220               3045.0                  34.028511
# 2098  2778339       180               3045.0                  34.028511
# 2118  4683198      1620               3045.0                  34.028511
#
#       Starting Station Longitude  Ending Station ID  Ending Station Latitude  \
# 2088                  -118.25667             3045.0                34.028511
# 2091                  -118.25667             3045.0                34.028511
# 2092                  -118.25667             3045.0                34.028511
# 2098                  -118.25667             3045.0                34.028511
# 2118                  -118.25667             3045.0                34.028511
#
# ...

# %%
MB4[['Duration','Start Day', 'End Day','Start year', 'End year', 'Start Month','End Month','Start Hour',
       'Start Min', 'Start Sec', 'End Hour', 'End Min', 'End Sec']].groupby(['Duration','Start Day', 'End Day','Start year', 'End year', 'Start Month','End Month','Start Hour',
       'Start Min', 'Start Sec', 'End Hour', 'End Min', 'End Sec']).size().reset_index()
# Out:
#        Duration  Start Day  End Day  Start year  End year  Start Month  \
# 0            60          1        1        2016      2016           10
# 1            60          1        1        2016      2016           12
# 2            60          2        2        2016      2016           10
# 3            60          2        2        2016      2016           12
# 4            60          2        2        2016      2016           12
# ...         ...        ...      ...         ...       ...          ...
# 11276     86400         15       17        2016      2016            8
# 11277     86400         15       18        2016      2016            8
# 11278     86400         16       17        2016      2016           10
# 11279     86400         26       28        2016      2016            8
# 11280     86400         28       31        2016      2016           10
#
#        End Month  Start Hour  Start Min  Start Sec  End Hour  End Min  \
# ...

# %%
MB4[['Passholder Type','Zip Codes']].groupby(['Passholder Type','Zip Codes']).size().reset_index()
# Out:
#    Passholder Type  Zip Codes     0
# 0        Flex Pass    22724.0     1
# 1        Flex Pass    22728.0   225
# 2        Flex Pass    23074.0   121
# 3        Flex Pass    23075.0    98
# 4        Flex Pass    23076.0    52
# 5        Flex Pass    23078.0   194
# 6        Flex Pass    23082.0    32
# 7     Monthly Pass    22724.0    78
# 8     Monthly Pass    22728.0  2611
# 9     Monthly Pass    23074.0  1071
# 10    Monthly Pass    23075.0  1026
# 11    Monthly Pass    23076.0   888
# 12    Monthly Pass    23078.0  1045
# 13    Monthly Pass    23082.0   124
# 14    Monthly Pass    24038.0    50
# 15         Walk-up    22724.0    60
# 16         Walk-up    22728.0  1280
# 17         Walk-up    23074.0   641
# 18         Walk-up    23075.0   530
# 19         Walk-up    23076.0   634
# 20         Walk-up    23078.0   903
# 21         Walk-up    23082.0    67
# 22         Walk-up    24038.0    25

# %%
MB4['Passholder Type'].unique()
# Out:
# array(['Monthly Pass', 'Walk-up', 'Flex Pass'], dtype=object)

# %%
MB4.rename(columns={'Passholder Type': 'Passholder_Type'}, inplace=True)

# %%
MB4.columns
# Out:
# Index(['Trip ID', 'Duration', 'Starting Station ID',
#        'Starting Station Latitude', 'Starting Station Longitude',
#        'Ending Station ID', 'Ending Station Latitude',
#        'Ending Station Longitude', 'Bike ID', 'Plan Duration',
#        'Trip Route Category', 'Passholder_Type', 'Starting Lat-Long',
#        'Ending Lat-Long', 'Neighborhood Councils (Certified)',
#        'Council Districts', 'Zip Codes', 'LA Specific Plans',
#        'Precinct Boundaries', 'Census Tracts', 'Start year', 'Start Month',
#        'Start Day', 'End year', 'End Month', 'End Day', 'Start Hour',
#        'Start Min', 'Start Sec', 'End Hour', 'End Min', 'End Sec'],
#       dtype='object')

# %%
MB4_count = MB4.groupby('Passholder_Type').Passholder_Type.count().sort_values(ascending=False).to_frame()

# %%
MB4_count.rename(columns={'Passholder_Type':"Count"},inplace=True)

# %%
MB4_count = MB4_count.reset_index()

# %%
MB4_count
# Out:
#   Passholder_Type  Count
# 0    Monthly Pass   6893
# 1         Walk-up   4140
# 2       Flex Pass    723

# %%
sns.set(rc={"figure.figsize" :(15,10)})
ax = sns.barplot(data=MB4_count,x='Passholder_Type',y='Count')
ax.tick_params(axis='x',rotation=90)

# %%
MB4["Trip Route Category"].unique()
# Out:
# array(['Round Trip', 'One Way'], dtype=object)

# %%
MB4.rename(columns={'Trip Route Category': 'Trip_Route_Category'}, inplace=True)

# %%
MB4_count = MB4.groupby('Trip_Route_Category').Trip_Route_Category.count().sort_values(ascending=False).to_frame()
MB4_count.rename(columns={'Trip_Route_Category':"Count"},inplace=True)
MB4_count = MB4_count.reset_index()
MB4_count
# Out:
#   Trip_Route_Category  Count
# 0             One Way  10311
# 1          Round Trip   1445

# %%
sns.set(rc={"figure.figsize" :(15,10)})
ax = sns.barplot(data=MB4_count,x='Trip_Route_Category',y='Count')
ax.tick_params(axis='x',rotation=90)

# %%
MB4[['Starting Station ID','Ending Station ID']].groupby(['Starting Station ID','Ending Station ID']).size().reset_index()
# Out:
#      Starting Station ID  Ending Station ID   0
# 0                 3005.0             3011.0  63
# 1                 3005.0             3014.0  40
# 2                 3005.0             3020.0  12
# 3                 3005.0             3025.0   9
# 4                 3005.0             3040.0  47
# ..                   ...                ...  ..
# 562               3082.0             3046.0  58
# 563               3082.0             3049.0  14
# 564               3082.0             3052.0  13
# 565               3082.0             3057.0   3
# 566               3082.0             3068.0  27
#
# [567 rows x 3 columns]

# %%
MB4.columns
# Out:
# Index(['Trip ID', 'Duration', 'Starting Station ID',
#        'Starting Station Latitude', 'Starting Station Longitude',
#        'Ending Station ID', 'Ending Station Latitude',
#        'Ending Station Longitude', 'Bike ID', 'Plan Duration',
#        'Trip_Route_Category', 'Passholder_Type', 'Starting Lat-Long',
#        'Ending Lat-Long', 'Neighborhood Councils (Certified)',
#        'Council Districts', 'Zip Codes', 'LA Specific Plans',
#        'Precinct Boundaries', 'Census Tracts', 'Start year', 'Start Month',
#        'Start Day', 'End year', 'End Month', 'End Day', 'Start Hour',
#        'Start Min', 'Start Sec', 'End Hour', 'End Min', 'End Sec'],
#       dtype='object')

# %%
sns.scatterplot(x='Trip ID',y='Bike ID',data=MB4,hue='Zip Codes')
# Out:
# <AxesSubplot: xlabel='Trip ID', ylabel='Bike ID'>

# %%
sns.distplot(MB4['Duration'])
# Out:
# C:\Users\Ram\AppData\Local\Temp\ipykernel_13700\1522483370.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(MB4['Duration'])
# <AxesSubplot: xlabel='Duration', ylabel='Density'>

# %%
sns.distplot(MB4['Starting Station ID'])
# Out:
# C:\Users\Ram\AppData\Local\Temp\ipykernel_13700\3128575031.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(MB4['Starting Station ID'])
# <AxesSubplot: xlabel='Starting Station ID', ylabel='Density'>

# %%
sns.distplot(MB4['Ending Station ID'])
# Out:
# C:\Users\Ram\AppData\Local\Temp\ipykernel_13700\1919187324.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(MB4['Ending Station ID'])
# <AxesSubplot: xlabel='Ending Station ID', ylabel='Density'>

# %%
MB4['Neighborhood Councils (Certified)'].head()
# Out:
# 2088    76.0
# 2091    76.0
# 2092    76.0
# 2098    76.0
# 2118    76.0
# Name: Neighborhood Councils (Certified), dtype: float64

# %%
MB4["Council Districts"].head()
# Out:
# 2088    9.0
# 2091    9.0
# 2092    9.0
# 2098    9.0
# 2118    9.0
# Name: Council Districts, dtype: float64

# %%
MB4_Council = MB4.groupby(['Neighborhood Councils (Certified)'])['Council Districts'].mean().sort_values(ascending=False).to_frame().reset_index()

# %%
sns.barplot(x='Neighborhood Councils (Certified)',y='Council Districts',data=MB4_Council)
# Out:
# <AxesSubplot: xlabel='Neighborhood Councils (Certified)', ylabel='Council Districts'>

# %%
MB4.columns
# Out:
# Index(['Trip ID', 'Duration', 'Starting Station ID',
#        'Starting Station Latitude', 'Starting Station Longitude',
#        'Ending Station ID', 'Ending Station Latitude',
#        'Ending Station Longitude', 'Bike ID', 'Plan Duration',
#        'Trip_Route_Category', 'Passholder_Type', 'Starting Lat-Long',
#        'Ending Lat-Long', 'Neighborhood Councils (Certified)',
#        'Council Districts', 'Zip Codes', 'LA Specific Plans',
#        'Precinct Boundaries', 'Census Tracts', 'Start year', 'Start Month',
#        'Start Day', 'End year', 'End Month', 'End Day', 'Start Hour',
#        'Start Min', 'Start Sec', 'End Hour', 'End Min', 'End Sec'],
#       dtype='object')

# %%
MB4["LA Specific Plans"].head()
# Out:
# 2088    7.0
# 2091    7.0
# 2092    7.0
# 2098    7.0
# 2118    7.0
# Name: LA Specific Plans, dtype: float64

# %%
 MB4.groupby(['LA Specific Plans'])['Zip Codes'].mean().sort_values(ascending=False).to_frame().reset_index()
# Out:
#    LA Specific Plans     Zip Codes
# 0                7.0  23035.651224
# 1               34.0  23035.035951
# 2               54.0  23018.914485
# 3               37.0  22927.962898
# 4               27.0  22903.224650

# %%
sns.barplot(x='LA Specific Plans',y='Zip Codes',data=MB4)
# Out:
# <AxesSubplot: xlabel='LA Specific Plans', ylabel='Zip Codes'>

# %%
MB4.groupby(['LA Specific Plans'])['Precinct Boundaries'].mean().sort_values(ascending=False).to_frame().reset_index()
# Out:
#    LA Specific Plans  Precinct Boundaries
# 0               27.0          1322.000000
# 1               34.0          1227.000000
# 2               37.0          1225.012367
# 3                7.0           931.661152
# 4               54.0           916.109948

# %%
sns.barplot(x='LA Specific Plans',y='Precinct Boundaries',data=MB4)
# Out:
# <AxesSubplot: xlabel='LA Specific Plans', ylabel='Precinct Boundaries'>

# %%
MB4.groupby(['LA Specific Plans'])['Duration'].mean().sort_values(ascending=False).to_frame().reset_index()
sns.barplot(x='LA Specific Plans',y='Duration',data=MB4, hue = "Plan Duration")
# Out:
# <AxesSubplot: xlabel='LA Specific Plans', ylabel='Duration'>

# %%
MB5 = MB4.copy()

# %%
MB5_1=MB5[['Trip_Route_Category', 'Passholder_Type', 'Starting Lat-Long','Ending Lat-Long']]
MB5_1.head(5)
# Out:
#      Trip_Route_Category Passholder_Type  \
# 2088          Round Trip    Monthly Pass
# 2091          Round Trip    Monthly Pass
# 2092          Round Trip    Monthly Pass
# 2098          Round Trip    Monthly Pass
# 2118          Round Trip    Monthly Pass
#
#                                       Starting Lat-Long  \
# 2088  {'longitude': '-118.25667', 'latitude': '34.02...
# 2091  {'longitude': '-118.25667', 'latitude': '34.02...
# 2092  {'longitude': '-118.25667', 'latitude': '34.02...
# 2098  {'longitude': '-118.25667', 'latitude': '34.02...
# 2118  {'longitude': '-118.25667', 'latitude': '34.02...
#
#                                         Ending Lat-Long
# 2088  {'longitude': '-118.25667', 'latitude': '34.02...
# 2091  {'longitude': '-118.25667', 'latitude': '34.02...
# 2092  {'longitude': '-118.25667', 'latitude': '34.02...
# 2098  {'longitude': '-118.25667', 'latitude': '34.02...
# 2118  {'longitude': '-118.25667', 'latitude': '34.02...

# %%
MB5_2 = MB5[['Trip ID', 'Duration', 'Starting Station ID',
       'Starting Station Latitude', 'Starting Station Longitude',
       'Ending Station ID', 'Ending Station Latitude',
       'Ending Station Longitude', 'Bike ID', 'Plan Duration',
       'Neighborhood Councils (Certified)',
       'Council Districts', 'Zip Codes', 'LA Specific Plans',
       'Precinct Boundaries', 'Census Tracts', 'Start year', 'Start Month',
       'Start Day', 'End year', 'End Month', 'End Day','Start Hour',
       'Start Min', 'Start Sec', 'End Hour', 'End Min', 'End Sec']]
MB5_2.head()
# Out:
#       Trip ID  Duration  Starting Station ID  Starting Station Latitude  \
# 2088  2023364      1980               3045.0                  34.028511
# 2091  2182651      4440               3045.0                  34.028511
# 2092  2286870      5220               3045.0                  34.028511
# 2098  2778339       180               3045.0                  34.028511
# 2118  4683198      1620               3045.0                  34.028511
#
#       Starting Station Longitude  Ending Station ID  Ending Station Latitude  \
# 2088                  -118.25667             3045.0                34.028511
# 2091                  -118.25667             3045.0                34.028511
# 2092                  -118.25667             3045.0                34.028511
# 2098                  -118.25667             3045.0                34.028511
# 2118                  -118.25667             3045.0                34.028511
#
# ...

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()
MB5_1 = MB5_1.apply(le.fit_transform)

# %%
MB5_1.head()
# Out:
#       Trip_Route_Category  Passholder_Type  Starting Lat-Long  Ending Lat-Long
# 2088                    1                1                 86                9
# 2091                    1                1                 86                9
# 2092                    1                1                 86                9
# 2098                    1                1                 86                9
# 2118                    1                1                 86                9

# %%
MB5 = pd.concat([MB5_1,MB5_2],axis = 1)

# %%
MB5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11756 entries, 2088 to 132426
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Trip_Route_Category                11756 non-null  int32
#  1   Passholder_Type                    11756 non-null  int32
#  2   Starting Lat-Long                  11756 non-null  int32
#  3   Ending Lat-Long                    11756 non-null  int32
#  4   Trip ID                            11756 non-null  int64
#  5   Duration                           11756 non-null  int64
#  6   Starting Station ID                11756 non-null  float64
#  7   Starting Station Latitude          11756 non-null  float64
#  8   Starting Station Longitude         11756 non-null  float64
#  9   Ending Station ID                  11756 non-null  float64
#  10  Ending Station Latitude            11756 non-null  float64
# ...

# %%
MB5.groupby(['Trip_Route_Category'])['Passholder_Type'].mean().sort_values(ascending=False).to_frame().reset_index()
sns.barplot(x='Trip_Route_Category',y='Passholder_Type',data=MB5)
# Out:
# <AxesSubplot: xlabel='Trip_Route_Category', ylabel='Passholder_Type'>

# %%
MB5.columns
# Out:
# Index(['Trip_Route_Category', 'Passholder_Type', 'Starting Lat-Long',
#        'Ending Lat-Long', 'Trip ID', 'Duration', 'Starting Station ID',
#        'Starting Station Latitude', 'Starting Station Longitude',
#        'Ending Station ID', 'Ending Station Latitude',
#        'Ending Station Longitude', 'Bike ID', 'Plan Duration',
#        'Neighborhood Councils (Certified)', 'Council Districts', 'Zip Codes',
#        'LA Specific Plans', 'Precinct Boundaries', 'Census Tracts',
#        'Start year', 'Start Month', 'Start Day', 'End year', 'End Month',
#        'End Day', 'Start Hour', 'Start Min', 'Start Sec', 'End Hour',
#        'End Min', 'End Sec'],
#       dtype='object')

# %%
MB6 = MB5.copy()

# %%
MB6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11756 entries, 2088 to 132426
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Trip_Route_Category                11756 non-null  int32
#  1   Passholder_Type                    11756 non-null  int32
#  2   Starting Lat-Long                  11756 non-null  int32
#  3   Ending Lat-Long                    11756 non-null  int32
#  4   Trip ID                            11756 non-null  int64
#  5   Duration                           11756 non-null  int64
#  6   Starting Station ID                11756 non-null  float64
#  7   Starting Station Latitude          11756 non-null  float64
#  8   Starting Station Longitude         11756 non-null  float64
#  9   Ending Station ID                  11756 non-null  float64
#  10  Ending Station Latitude            11756 non-null  float64
# ...

# %%
MB6["LA Specific Plans"].head()
# Out:
# 2088    7.0
# 2091    7.0
# 2092    7.0
# 2098    7.0
# 2118    7.0
# Name: LA Specific Plans, dtype: float64

# %%
MB6['Trip_Route_Category'].head()
# Out:
# 2088    1
# 2091    1
# 2092    1
# 2098    1
# 2118    1
# Name: Trip_Route_Category, dtype: int32

# %%
from pandas.plotting import scatter_matrix

MB6 = pd.DataFrame(np.random.randn(1000, 4), columns=["Starting Station Latitude", "Ending Station Latitude", "Starting Station Longitude", "Ending Station Longitude"])

scatter_matrix(MB6, alpha=0.2, figsize=(10, 10), diagonal="kde");

# %%
MB4.groupby(['Trip_Route_Category'])['LA Specific Plans'].mean().sort_values(ascending=False).to_frame().reset_index()

sns.barplot(x='Trip_Route_Category',y='LA Specific Plans',data=MB4, hue ='Passholder_Type')
# Out:
# <AxesSubplot: xlabel='Trip_Route_Category', ylabel='LA Specific Plans'>

# %%
MB4.groupby(['Start Hour'])['LA Specific Plans'].mean().sort_values(ascending=False).to_frame().reset_index()

sns.barplot(x='Start Hour',y='LA Specific Plans',data=MB4, hue ='Passholder_Type')
# Out:
# <AxesSubplot: xlabel='Start Hour', ylabel='LA Specific Plans'>

# %%
MB4.groupby(['End Hour'])['LA Specific Plans'].mean().sort_values(ascending=False).to_frame().reset_index()

sns.barplot(x='End Hour',y='LA Specific Plans',data=MB4, hue ='Passholder_Type')
# Out:
# <AxesSubplot: xlabel='End Hour', ylabel='LA Specific Plans'>

# %%
sns.barplot(x='Start Day',y='LA Specific Plans',data=MB4, hue ='Passholder_Type')
# Out:
# <AxesSubplot: xlabel='Start Day', ylabel='LA Specific Plans'>

# %%
sns.barplot(x='Start Month',y='LA Specific Plans',data=MB4, hue ='Passholder_Type')
# Out:
# <AxesSubplot: xlabel='Start Month', ylabel='LA Specific Plans'>
